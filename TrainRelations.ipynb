# %% [markdown]
# <a href="https://colab.research.google.com/github/PunkGoesPop/Hello-world/blob/master/TrainRelations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
#ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

model.fit(xs, epochs=50)

print(model.predict([2.0]))
# Out:
# Train on 3 samples
# Epoch 1/50
# 3/3 [==============================] - 0s 67ms/sample - loss: 8.6888
# Epoch 2/50
# 3/3 [==============================] - 0s 1ms/sample - loss: 2.1475
# Epoch 3/50
# 3/3 [==============================] - 0s 853us/sample - loss: 0.5835
# Epoch 4/50
# 3/3 [==============================] - 0s 989us/sample - loss: 0.2093
# Epoch 5/50
# 3/3 [==============================] - 0s 898us/sample - loss: 0.1195
# Epoch 6/50
# 3/3 [==============================] - 0s 880us/sample - loss: 0.0978
# Epoch 7/50
# 3/3 [==============================] - 0s 733us/sample - loss: 0.0922
# Epoch 8/50
# 3/3 [==============================] - 0s 817us/sample - loss: 0.0906
# Epoch 9/50
# 3/3 [==============================] - 0s 650us/sample - loss: 0.0899
# Epoch 10/50
# 3/3 [==============================] - 0s 584us/sample - loss: 0.0894
# Epoch 11/50
# 3/3 [==============================] - 0s 620us/sample - loss: 0.0890
# Epoch 12/50
# ...
