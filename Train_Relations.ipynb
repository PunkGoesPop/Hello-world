# %% [markdown]
# <a href="https://colab.research.google.com/github/PunkGoesPop/Hello-world/blob/master/Train_Relations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

model.fit(xs, ys, epochs=50)

print(model.predict([2.0]))
# Out:
# Train on 6 samples
# Epoch 1/50
# 6/6 [==============================] - 0s 58ms/sample - loss: 19.3768
# Epoch 2/50
# 6/6 [==============================] - 0s 448us/sample - loss: 15.2653
# Epoch 3/50
# 6/6 [==============================] - 0s 344us/sample - loss: 12.0302
# Epoch 4/50
# 6/6 [==============================] - 0s 366us/sample - loss: 9.4845
# Epoch 5/50
# 6/6 [==============================] - 0s 353us/sample - loss: 7.4813
# Epoch 6/50
# 6/6 [==============================] - 0s 325us/sample - loss: 5.9049
# Epoch 7/50
# 6/6 [==============================] - 0s 371us/sample - loss: 4.6643
# Epoch 8/50
# 6/6 [==============================] - 0s 373us/sample - loss: 3.6878
# Epoch 9/50
# 6/6 [==============================] - 0s 343us/sample - loss: 2.9192
# Epoch 10/50
# 6/6 [==============================] - 0s 331us/sample - loss: 2.3141
# Epoch 11/50
# 6/6 [==============================] - 0s 338us/sample - loss: 1.8377
# Epoch 12/50
# ...
